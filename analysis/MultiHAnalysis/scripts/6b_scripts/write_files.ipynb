# %%
import glob, subprocess

# %%
mps = glob.glob("/eos/uscms/store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/*/*")

# %%
# mps = [mp for mp in mps if 'MX_1100' in mp]
mps
# Out:
# ['/eos/uscms/store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_250_sl7_nano/240522_195415',
#  '/eos/uscms/store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_300_sl7_nano/240522_195530',
#  '/eos/uscms/store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_350_sl7_nano/240522_195645',
#  '/eos/uscms/store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_400_sl7_nano/240522_195800',
#  '/eos/uscms/store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_450_sl7_nano/240522_195914',
#  '/eos/uscms/store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_500_sl7_nano/240522_200028',
# ...

# %%
for mp in mps:
    cmd = f"python3 scripts/6b_scripts/write_input_file.py -a 6b --year 2017 --dir {mp.replace('/eos/uscms','')}/"
    print(cmd)
    print(subprocess.check_output(cmd, shell=True).decode('utf-8'))
# Out:
# python3 scripts/6b_scripts/write_input_file.py -a 6b --year 2017 --dir /store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_250_sl7_nano/240522_195415/
# .. parsing argument line
# .. writing to file: input/PrivateMC/NMSSM_XYH_YToHH_6b/Private_2017/NMSSM_XYH_YToHH_6b_MX_1000_MY_250.txt
# ['0000', '']
#
# python3 scripts/6b_scripts/write_input_file.py -a 6b --year 2017 --dir /store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_300_sl7_nano/240522_195530/
# .. parsing argument line
# .. writing to file: input/PrivateMC/NMSSM_XYH_YToHH_6b/Private_2017/NMSSM_XYH_YToHH_6b_MX_1000_MY_300.txt
# ['0000', '']
#
# python3 scripts/6b_scripts/write_input_file.py -a 6b --year 2017 --dir /store/group/lpchbb/srosenzw/XYH_YToHH/Summer2017UL/CRAB_PrivateMC/srosenzw_NMSSM_XYH_YToHH_6b_MX_1000_MY_350_sl7_nano/240522_195645/
# .. parsing argument line
# ...
